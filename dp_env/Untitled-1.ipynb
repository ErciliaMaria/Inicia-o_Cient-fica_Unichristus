# %%
print("hello world")
# Out:
# Running cells with 'Python 3.12.3' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '/usr/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# # Debugando Privacidade Diferencial
# Este notebook serve para testar e depurar funções de privacidade diferencial no seu ambiente virtual correto.

# %%
# Exemplo: carregando um CSV para análise
import pandas as pd
df = pd.read_csv('../federated_health_dataset.csv')
df.head()

# %%
# Exemplo: função e debug interativo
def soma_privada(a, b):
    return a + b

import pdb; pdb.set_trace()  # breakpoint interativo
resultado = soma_privada(2, 3)
print('Resultado:', resultado)
