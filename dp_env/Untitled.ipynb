# %%
print("Hello")
# Out:
# Hello

# %%
import pandas as pd

# %%
import numpy as np

# %%
nome_do_arquivo = 'diabetes.csv'
df = pd.read_csv(nome_do_arquivo)
print("Arquivo 'diabetes.csv' carregado com sucesso!")
# Out:
# Arquivo 'diabetes.csv' carregado com sucesso!

# %%
media_idade_real = df['Age'].mean()

# %%
print(media_idade_real)
# Out:
# 33.240885416666664

# %%
epsilon = 1.5     
max_idade = 100    
sensibilidade = max_idade

# %%
soma_idade_real = df['Age'].sum()
contagem_idade = df['Age'].count()
